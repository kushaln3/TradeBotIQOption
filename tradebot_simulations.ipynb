# %%
import time
import random

total_balance = 1
trade_amount = 1
return_percent = 90 /100
time_per_trade = 3

# %%
def trade(option, trade_amount, time_per_trade = 3):
    global total_balance
    if trade_amount > total_balance:
        print('Not enogh money to place trade')
        return

    total_balance -= trade_amount

    trade_result = random.randint(0,1) # 0 means call and 1 mean put

    if option == 'call' or option == 'buy':
        print(f"{option} trade executed successfully.\nShowing result in {time_per_trade} seconds...")
        time.sleep(time_per_trade)
        if trade_result == 0:
            total_balance += round(trade_amount + trade_amount*return_percent, 1)
            print(f"\nOption: {option}\nTrade amount: {trade_amount}\nResult: PROFIT\nProfit: {trade_amount*return_percent}\nTotal balance: {total_balance}\n")
        else:
            print(f"\nOption: {option}\nTrade amount: {trade_amount}\nResult: LOSS\nLoss: {trade_amount}\nTotal balance: {total_balance}\n")

    elif option == 'put' or option == 'sell':
        print(f"{option} trade executed successfully.\nShowing result in {time_per_trade} seconds...")
        time.sleep(time_per_trade)
        if trade_result == 1:
            total_balance += round(trade_amount + trade_amount*return_percent, 1)
            print(f"\nOption: {option}\nTrade amount: {trade_amount}\nResult: PROFIT\nProfit: {trade_amount*return_percent}\nTotal balance: {total_balance}\n")
        else:
            print(f"\nOption: {option}\nTrade amount: {trade_amount}\nResult: LOSS\nLoss: {trade_amount}\nTotal balance: {total_balance}\n")

    else:
        print('Error: Invalid option')
# Out:
# Streaming output truncated to the last 5000 lines.
# Result: LOSS
# Loss: 1
# Total balance: 33.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 32.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 33.199999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 32.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 33.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 34.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 34.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 33.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 34.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 33.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 32.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 31.799999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 32.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 31.700000000000003
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 32.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 33.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 32.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 33.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 32.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 31.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 30.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 29.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 30.299999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 29.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 28.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 29.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 28.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 27.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 28.099999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 27.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 26.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 27.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 27.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 26.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 25.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 24.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 23.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 22.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 23.799999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 22.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 21.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 22.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 23.599999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 22.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 21.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 20.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 19.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 18.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 17.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 18.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 17.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 16.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 15.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 16.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 15.399999999999999
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 16.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 17.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 18.099999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 19.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 19.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 20.799999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 19.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 20.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 21.599999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 20.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 19.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 18.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 19.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 20.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 21.299999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 20.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 21.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 20.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 21.099999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 22.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 21.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 21.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 20.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 21.799999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 22.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 23.599999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 24.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 25.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 26.299999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 25.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 26.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 27.099999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 26.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 27.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 27.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 28.799999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 29.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 30.599999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 31.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 32.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 33.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 34.199999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 35.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 34.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 33.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 32.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 31.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 30.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 31.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 31.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 32.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 33.699999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 34.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 35.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 34.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 35.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.199999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 34.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 33.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 33.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 34.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 33.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 34.699999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 35.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 37.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 36.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 34.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 35.199999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 37.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 36.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 34.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 33.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 34.699999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 33.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 34.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 35.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 37.199999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 38.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 39.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 38.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 37.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 37.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 38.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 39.699999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 38.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 37.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 38.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 39.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 40.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 41.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 40.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 39.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 40.199999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 41.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 42.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 41.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 40.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 39.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 38.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 38.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 37.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 36.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 37.699999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 38.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 37.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 36.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 34.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 33.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 34.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 35.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 34.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 35.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.199999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 37.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 37.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 36.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 37.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 36.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 34.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 33.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 34.699999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 35.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 34.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 35.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 37.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 36.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 37.199999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 36.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 37.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 38.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 37.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 36.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 34.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 34.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 33.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 34.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 35.699999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 36.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 35.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 34.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 33.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 32.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 31.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 30.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 29.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 28.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 27.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 28.299999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 29.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 28.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 29.099999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 28.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 29.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 29.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 28.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 29.799999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 28.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 27.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 28.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 27.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 28.599999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 29.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 28.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 27.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 26.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 27.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 26.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 25.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 26.299999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 27.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 26.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 25.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 24.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 23.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 22.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 21.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 22.099999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 21.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 22.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 22.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 21.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 22.799999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 23.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 24.599999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 23.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 22.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 23.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 22.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 23.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 22.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 21.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 22.299999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 23.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 24.099999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 25.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 24.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 24.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 25.799999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 26.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 27.599999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 26.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 25.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 24.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 23.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 22.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 23.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 22.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 21.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 22.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 21.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 22.299999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 21.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 22.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 23.099999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 24.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 24.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 23.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 24.799999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 23.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 24.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 25.599999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 26.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 25.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 24.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 25.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 24.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 23.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 22.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 21.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 22.299999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 23.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 24.099999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 25.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 24.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 23.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 23.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 24.799999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 23.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 22.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 21.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 20.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 19.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 18.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 19.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 18.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 19.599999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 18.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 19.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 18.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 17.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 18.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# ...
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 15.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 14.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 13.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 14.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 13.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 12.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 11.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 10.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 11.700000000000001
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 12.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 11.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 12.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 11.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 12.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 13.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 14.200000000000001
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 13.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 12.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 11.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 10.2
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 11.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 12.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 11.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 10.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 10.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 9.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 8.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 7.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 8.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 7.800000000000001
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 6.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 7.699999999999999
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 6.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 7.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 6.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 5.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 4.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 5.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 6.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 5.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 6.300000000000001
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 5.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 6.199999999999999
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 7.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 6.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 5.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 6.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 6.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 5.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 6.800000000000001
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 5.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 6.699999999999999
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 7.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 6.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 7.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 6.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 5.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 4.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 3.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 4.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 3.4000000000000004
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 2.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 3.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 4.199999999999999
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 5.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 4.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 5.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 4.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 4.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 5.800000000000001
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 4.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 3.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 4.699999999999999
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 3.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 4.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 3.5999999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 4.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 3.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 4.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 3.4000000000000004
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 4.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 3.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 2.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 3.1999999999999997
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 4.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 3.0999999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 4.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 4.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 5.800000000000001
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 4.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 5.699999999999999
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 4.7
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 5.6
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 6.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 5.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 4.5
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 5.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 4.4
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 3.4000000000000004
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 4.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 3.3
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 4.199999999999999
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 5.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 4.1
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 3.0999999999999996
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 4.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 3.0
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 3.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 2.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 1.9
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: PROFIT
# Profit: 0.9
# Total balance: 2.8
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 1.7999999999999998
#
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 0.8
#
# 19585

# %%
no_of_trades = 0
while total_balance>0:
  trade('call',1,0)
  no_of_trades+=1

# %%
# total_balance = 1
trade('call',1,0)
# Out:
# call trade executed successfully.
# Showing result in 0 seconds...
#
# Option: call
# Trade amount: 1
# Result: LOSS
# Loss: 1
# Total balance: 0.8999999999999999

# %%
print(round(0.9, 1))
# Out:
# 0.9
